# %%
# !pip install cupy
# Out:
# ...
#      ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.5 MB 65.4 kB/s eta 0:00:54
#      ---------------------------------------- 0.0/3.5 MB 65.4 kB/s eta 0:00:54
#      ---------------------------------------- 0.0/3.5 MB 65.4 kB/s eta 0:00:54
#      ---------------------------------------- 0.0/3.5 MB 65.4 kB/s eta 0:00:54
#      ---------------------------------------- 0.0/3.5 MB 65.4 kB/s eta 0:00:54
#      ---------------------------------------- 0.0/3.5 MB 65.4 kB/s eta 0:00:54
# ...

# %%
import cucim
import cupy as cp
import matplotlib.pyplot as plt

# Rutas de entrada y salida
input_path = "img.jpg"
output_path = "test.png"

# Cargar la imagen utilizando cuCIM
input_image = cucim.load(input_path)

# Convertir la imagen a un arreglo NumPy en la GPU
input_array_gpu = cp.asarray(input_image)

# Procesar la imagen (por ejemplo, eliminar el fondo)
# Aquí puedes aplicar tu proceso de eliminación de fondo, 
# dependiendo de las capacidades de cuCIM o de otras bibliotecas compatibles con CUDA

# Convertir el resultado de nuevo a un arreglo NumPy en la CPU
output_array_cpu = cp.asnumpy(input_array_gpu)

# Guardar la imagen procesada
output_image = Image.fromarray(output_array_cpu)
output_image.save(output_path)

# Mostrar ambas imágenes en una figura de Matplotlib
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# Mostrar la imagen original en el primer eje
axes[0].imshow(input_image)
axes[0].set_title('Imagen original')
axes[0].axis('off')

# Mostrar la imagen procesada en el segundo eje
axes[1].imshow(output_image)
axes[1].set_title('Imagen procesada')
axes[1].axis('off')

# Mostrar la figura
plt.show()
